# %%
#Loading in Packages and Data

#Importing Packages
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.ticker as ticker
import matplotlib.cm as cm
from matplotlib.colors import Normalize
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import ScalarFormatter
import matplotlib.gridspec as gridspec
import xarray as xr
import os; import time
import pickle
import h5py
###############################################################
def coefs(coefficients,degree):
    coef=coefficients
    coefs=""
    for n in range(degree, -1, -1):
        string=f"({coefficients[len(coef)-(n+1)]:.1e})"
        coefs+=string + f"x^{n}"
        if n != 0:
            coefs+=" + "
    return coefs
###############################################################
start_time = time.time();

#Importing Model Data
check=False
dir='/mnt/lustre/koa/koastore/torri_group/air_directory/DCI-Project/'
job_array=False;index_adjust=0

# # dx = 1 km; Np = 1M; Nt = 5 min
# data=xr.open_dataset(dir+'../cm1r20.3/run/cm1out_1km_5min.nc') #***
# parcel=xr.open_dataset(dir+'../cm1r20.3/run/cm1out_pdata_1km_5min_1e6.nc') #***
# t_res='5min'; res='1km'
# Np_str='1e6'

# dx = 1km; Np = 50M
#Importing Model Data
check=False
dir2='/home/air673/koa_scratch/'
data=xr.open_dataset(dir2+'cm1out_1km_1min.nc') #***
parcel=xr.open_dataset(dir2+'cm1out_pdata_1km_1min_50M.nc') #***
res='1km'; t_res='1min'; Np_str='50e6'

# # dx = 1km; Np = 100M
# #Importing Model Data
# check=False
# dir2='/home/air673/koa_scratch/'
# data=xr.open_dataset(dir2+'cm1out_1km_1min.nc') #***
# parcel=xr.open_dataset(dir2+'cm1out_pdata_1km_1min_100M.nc') #***
# res='1km'; t_res='1min'; Np_str='100e6'

# # dx = 250 m
# #Importing Model Data
# check=False
# dir2='/home/air673/koa_scratch/'
# data=xr.open_dataset(dir2+'cm1out_250m.nc') #***
# parcel=xr.open_dataset(dir2+'cm1out_pdata_250m.nc') #***
# res='250m'
# Np_str='150e6'

# %%
def check_memory():
    import sys
    ipython_vars = ["In", "Out", "exit", "quit", "get_ipython", "ipython_vars"]
    print("Top 10 objects with highest memory usage")
    # Get a sorted list of the objects and their sizes
    mem = {
        key: round(value/1e6,2)
        for key, value in sorted(
            [
                (x, sys.getsizeof(globals().get(x)))
                for x in globals()
                if not x.startswith("_") and x not in sys.modules and x not in ipython_vars
            ],
            key=lambda x: x[1],
            reverse=True)[:10]
    }
    print({key:f"{value} MB" for key,value in mem.items()})
    print(f"\n{round(sum(mem.values()),2)/1000} GB in use overall")

# %%
############################################################################################

times=data['time'].values/(1e9 * 60); times=times.astype(float);
minutes=1/times[1] #1 / minutes per timestep = timesteps per minute
kms=np.argmax(data['xh'].values-data['xh'][0].values >= 1)

#LOADING CL MAXS FROM CL TRACKING ALGORITHM
folder = '/mnt/lustre/koa/koastore/torri_group/air_directory/DCI-Project/Project_Algorithms/Tracking_Algorithms/'
open_name = folder+f'whereCL_{res}_{t_res}_ALL_CLS.nc'
whereCL=xr.open_dataset(open_name).load()
whereCL=whereCL.isel(time=slice(0,len(data['time'])))
whereCL=whereCL['maxconv_x']
def Get_Conv_X(t,z,y):
    Conv_X_Max=whereCL[t,z,y,:].values
    return Conv_X_Max

# %%
#JOB ARRAY SETUP
job_array=True
if job_array==True:

    num_jobs=350 #how many total jobs are being run? i.e. array=1-100 ==> num_jobs=100 #***
    total_elements=len(parcel['xh']) #total num of variables

    if num_jobs >= total_elements:
        raise ValueError("Number of jobs cannot be greater than or equal to total elements.")
    
    job_range = total_elements // num_jobs  # Base size for each chunk
    remaining = total_elements % num_jobs   # Number of chunks with 1 extra 
    
    # Function to compute the start and end for each job_id
    def get_job_range(job_id):
        job_id-=1
        # Add one extra element to the first 'remaining' chunks
        start_job = job_id * job_range + min(job_id, remaining)
        end_job = start_job + job_range + (1 if job_id < remaining else 0)
    
        if job_id == num_jobs - 1: 
            end_job = total_elements #- 1
        return start_job, end_job
    # def job_testing():
    #     #TESTING
    #     start=[];end=[]
    #     for job_id in range(1,num_jobs+1):
    #         start_job, end_job = get_job_range(job_id)
    #         print(start_job,end_job)
    #         start.append(start_job)
    #         end.append(end_job)
    #     print(np.all(start!=end))
    #     print(len(np.unique(start))==len(start))
    #     print(len(np.unique(end))==len(end))
    # job_testing()
    
    job_id = int(os.environ.get('SLURM_ARRAY_TASK_ID', 0)) #this is the current SBATCH job id
    if job_id==0: job_id=1
    start_job, end_job = get_job_range(job_id)
    index_adjust=start_job
    print(f'start_job = {start_job}, end_job = {end_job}')
# Out:
# start_job = 0, end_job = 144723

# %%
#SUBSETTING PARCEL DATA
parcel=parcel.isel(xh=slice(start_job,end_job))

# %%
# Reading Back Data Later
##############
import h5py
dir2=dir+'Project_Algorithms/Lagrangian_Arrays/'
open_file=dir2+f'lagrangian_binary_array_{res}_{t_res}_{Np_str}.h5'
with h5py.File(open_file, 'r') as f:
    parcel_z = f['z'][:,start_job:end_job]
    parcel_x = f['x'][:,start_job:end_job] #*#
    
    # Load the dataset by its name

    W = f['W'][:,start_job:end_job]
    Z = f['Z'][:,start_job:end_job]
    Y = f['Y'][:,start_job:end_job]
    X = f['X'][:,start_job:end_job]

# %%
# # Reading Back Data Later
# ##############
# import h5py
# dir2=dir+'Project_Algorithms/Lagrangian_Binary_Array/'
# with h5py.File(dir2+f'LFC_LCL_binary_array.h5', 'r') as f:
#     # Load the dataset by its name
#     LFC = f['LFC'][:]
#     LCL = f['LCL'][:]

# Reading Back Data Later
##############
import h5py
dir2=dir+'Project_Algorithms/Lagrangian_Arrays/'
open_file=dir2+f'LFC_LCL_binary_array_{res}_{t_res}_{Np_str}.h5'
with h5py.File(open_file, 'r') as f:
    # Load the dataset by its name
    LFC = f['LFC'][:,start_job:end_job]
    LCL = f['LCL'][:,start_job:end_job]

# %%
check_memory()
# Out:
# Top 10 objects with highest memory usage
# {'parcel_z': '382.65 MB', 'parcel_x': '382.65 MB', 'W': '382.65 MB', 'Z': '191.32 MB', 'Y': '191.32 MB', 'X': '191.32 MB', 'LFC': '95.66 MB', 'LCL': '95.66 MB', 'times': '0.01 MB', 'NamespaceMagics': '0.0 MB'}
#
# 1.91324 GB in use overall

# %%
#################################################################

# %%
#Updated Lagrangian Tracking Algorithm

#Algorithm Steps:
#(1) Find the first time a parcel is above the LFC:
#(2) First check if the parcel ascends (w>=0.1) for another 20 minutes
#(3) If so, find first time, the parcel slows down (w<0.1)
#(4) If that time is when the parcel is above 750m, save it, "forget", and move on to next parcel
#(5) If that time is when the parcel is below 750m, check if it is within 2km of the CL_Max found from the CL Tracking Algorithm
#(6) If the parcel is near the CL, store in, otherwise save it, "forget", and move on to next parcel
#(7) Continue to next parcel

#(Also, if during, traceback, the parcel escapes the x or z boundary, "forget" parcel, and move on)

# %%
#Numerical Settings
Nt=len(data['time'])
Np=len(parcel['xh'])
dt=times[1]*60
print(f"(Nt,Np,dt) {Nt,Np,dt}")

#For saving ascend-after-LFC info
ascend_lst=[]
CLmaxheight=750 #750m

#BL slow-down-threshold
w_thresh=0.1
# Out:
# (Nt,Np,dt) (661, 144723, 60.0)

# %%
# #OLD CODE (USE BELOW INSTEAD)
# t_by_t=False#LOAD IN ALL AT ONCE (TOO SLOW)
# # t_by_t=True

# if t_by_t==False:
#     print('loading in lagrangian u and w')
#     parcel_u=parcel['u'].data 
#     parcel_w=parcel['w'].data
#     print('done')

# elif t_by_t==True:
#     Nt = len(parcel['time'])
#     Np = len(parcel['xh'])  
    
#     # Initialize final output array
#     def create_empty():
#         out=np.empty((Nt, Np), dtype=np.float32)
#         return out
#     parcel_u = create_empty()
#     parcel_w = create_empty()
    
#     # Load and process timestep-by-timestep
#     for t in range(Nt):
#         if np.mod(t,50)==0: print(f'time = {t}')
#         parcel_u[t, :] = parcel['u'].isel(time=t).data
#         parcel_w[t, :] = parcel['w'].isel(time=t).data
#     print('done')

# %%
#u,w are now added to Lagrangian_Binary_Array results, no need for code above
# Reading Back Data Later
##############
import h5py
dir2=dir+'Project_Algorithms/Lagrangian_Arrays/'
open_file=dir2+f'lagrangian_binary_array_{res}_{t_res}_{Np_str}.h5'
with h5py.File(open_file, 'r') as f:
    parcel_u = f['u'][:,start_job:end_job]
    parcel_w = f['w'][:,start_job:end_job] #*#

# %%
check_memory() #Needs about 3.25G per job ==> request 8G (actually 12G needed)
# Out:
# Top 10 objects with highest memory usage
# {'parcel_z': '382.65 MB', 'parcel_x': '382.65 MB', 'W': '382.65 MB', 'parcel_u': '382.65 MB', 'parcel_w': '382.65 MB', 'Z': '191.32 MB', 'Y': '191.32 MB', 'X': '191.32 MB', 'LFC': '95.66 MB', 'LCL': '95.66 MB'}
#
# 2.6785300000000003 GB in use overall

# %%
# if ((x + dt*u)==0) or ((z + dt*w)==0)
# u=u[t,Z[t,p],Y[t,p],X[t,p]]; W=W[t,p]
# [u[t,Z[t,p],Y[t,p],X[t,p]] for t in time_arr] >np.max(data['xf'].values) or < np.min(data['xf'].values)
# similarly for w
################################################################################################################
#BOUNDARY-ESCAPE CONDITION
xmin=np.min(data['xf'].values)*1e3
xmax=np.max(data['xf'].values)*1e3
zmin=np.min(data['zf'].values)*1e3
zmax=np.max(data['zf'].values)*1e3

def check_boundary(p,where_BL,above_LFC):
    time_arr=np.arange(where_BL,above_LFC)

    def get_x(t,p):
        # return parcel['x'][t,p].item()
        return parcel_x[t,p] 
    def get_u(t,p):
        # return data['uinterp'].isel(time=t,zh=Z[t,p],yh=Y[t,p],xh=X[t,p]).item() #TESTING
        # return parcel['u'][t,p].item() 
        return parcel_u[t,p]
    def get_z(t,p):
        # return parcel['z'][t,p].item()
        return parcel_z[t,p]
    def get_w(t,p):
        # return data['winterp'].isel(time=t,zh=Z[t,p],yh=Y[t,p],xh=X[t,p]).item()
        # return parcel['w'][t,p].item()
        return parcel_w[t,p]
        

    # x_tend = [get_x(t, p) + dt * get_u(t, z, y, x)   #THIS IS OLD, LESS IDEAL
    #       for (t, z, y, x) in zip(time_arr, Z[time_arr, p], Y[time_arr, p], X[time_arr, p])] 
    # z_tend = [get_z(t, p) + dt * get_w(t, z, y, x)  
    #       for (t, z, y, x) in zip(time_arr, Z[time_arr, p], Y[time_arr, p], X[time_arr, p])] 
    
    x_tend = [get_x(t, p) + dt * get_u(t,p)   
          for (t, z, y, x) in zip(time_arr, Z[time_arr, p], Y[time_arr, p], X[time_arr, p])] 
    z_tend = [get_z(t, p) + dt * get_w(t,p)  
          for (t, z, y, x) in zip(time_arr, Z[time_arr, p], Y[time_arr, p], X[time_arr, p])] 

    x_bound=any(val < xmin or val > xmax for val in x_tend)*1
    z_bound=any(val < zmin or val > zmax for val in z_tend)*1

    out=(x_bound,z_bound)
    if out[0]==1:
        print(f'parcel {p} crossed x-boundary between t={where_BL} and t={above_LFC}')
    elif out[1]==1:
        print(f'parcel {p} crossed z-boundary between t={where_BL} and t={above_LFC}')
    return out
#############################################################################################################

# %%
#############################################################################################################
#The Algorithm

# %%
#Initialize Output Storage Vector

#int 32 can store up to the number 2,147,483,647 
#int 32 has 4 bytes per number, so needs (Np*3)*4 bytes of memory
#Np=125000 ==> (125000*3*4)/(1024**3) = 0.001 GB
#Np=50e6 ==> (50e6*3*4)/(1024**3) = 0.56 GB

out_arr=np.zeros((Np,3),dtype=np.int32) 
save_arr=np.zeros((Np,3),dtype=np.int32) #This one is for saving continued-ascent, slow-below-750m parcels that are not with 2 km of CL
save2_arr=np.zeros((Np,3),dtype=np.int32) #This one is for saving continued-ascent, slow-above-750m parcels

# %%
#1--------------Looping over each parcel
for count,p in enumerate(np.arange(Np)): 

    if np.mod(p,5e4)==0: print(f'current parcel: {p}/{Np}')
    
    W_p = W[:,p]
    LFC_p = LFC[:,p] 
   
    #----FIND WHERE PARCEL IS ABOVE LFC----
    indices = np.where(LFC_p == 1)[0]; above_LFC = indices[0] if indices.size > 0 else -999; #FIRST TIME ABOVE LFC
    if above_LFC ==-999:
        # print(f'parcel {p} never above LFC')
        continue #if the parcel is never above the LFC, skip the parcel
    
    #----CHECK IF ASCENDS FOR >= 20 minutes AFTER LFC----
    ascend_array=W_p[above_LFC+1:]
    indices=np.where(ascend_array==0)[0]; ascend_stop=indices[0] if indices.size > 0 else 10000; #location of where parcel stops ascending (labeled 10000 to mark for future analysis)
    ascend_lst.append(ascend_stop) #(also store for histogram)
    if ascend_stop>=20*minutes:
    
        #----FIND THE FIRST TIME W_p<=w_thresh----
        indices=np.where(W_p[0:above_LFC]<w_thresh)[0]
        where_BL=indices[-1] if indices.size > 0 else -999 #FIRST PRIOR TIME W<0.1 (IN THE BL) (ADDED 1 TO GET TIME RIGHT AFTER INTERACTION)
        if where_BL ==-999:
            # print(f'parcel {p} w is never below threshold prior to t={above_LFC}')
            continue #if the parcel never slows down backwards in time (unlikely), skip the parcel
            
        #check for boundary escapes
        ################################
        future_location=check_boundary(p,where_BL,above_LFC)
        if (future_location[0]+future_location[1]>=1): continue #if parcel crosses boundary, skips current parcel
        ################################
        
        #----CHECK IF PARCEL SLOWED DOWN LOW ENOUGH----
        if parcel_z[where_BL,p]<=CLmaxheight: #PARCEL MUST BE BELOW 750m WHEN CONTACTING CL #***
        # if LCL[where_BL,p]==0: #PARCEL MUST BE BELOW LCL WHEN CONTACTING CL (not recommended)
    
            #----CHECK IF CL IS WITHIN 2km----
            #Find the CL-max x-location
            t=where_BL; z=Z[where_BL,p]; y=Y[where_BL,p]; x=X[where_BL,p]
            CONV_X=Get_Conv_X(t,z,y)
            within_CL=np.any(np.isin(CONV_X, np.arange(x-2*kms,x+3*kms)))
            
            if within_CL==True:
                #save X's (t,p) 
                print(f'Parcel {p} is success at time {where_BL}')
                out_arr[p,0]=p
                out_arr[p,1]=where_BL
                out_arr[p,2]=above_LFC 
            else: #continued-ascent, slow-below-750m parcels that are not with 2 km of CL
                #SAVE PARCEL
                # print(f'Parcel {p} not near CL at t={where_BL}')
                save_arr[p,0]=p
                save_arr[p,1]=where_BL
                save_arr[p,2]=above_LFC 
    
        else: #continued-ascent, slow-above-750m parcels
            #SAVE PARCEL
            # print(f'Parcel {p} above {CLmaxheight}m at t={where_BL}')
            save2_arr[p,0]=p
            save2_arr[p,1]=where_BL
            save2_arr[p,2]=above_LFC         
            
        #END OF LOOP, THEN WE MOVE ON TO NEXT PARCEL p
# Out:
# current parcel: 0/144723
# Parcel 31 is success at time 295
# Parcel 87 is success at time 413
# Parcel 155 is success at time 278
# Parcel 162 is success at time 425
# Parcel 163 is success at time 280
# Parcel 194 is success at time 405
# Parcel 262 is success at time 341
# Parcel 273 is success at time 278
# Parcel 287 is success at time 291
# Parcel 394 is success at time 298
# Parcel 402 is success at time 398
# Parcel 468 is success at time 354
# Parcel 493 is success at time 400
# Parcel 538 is success at time 324
# Parcel 599 is success at time 255
# Parcel 683 is success at time 361
# Parcel 694 is success at time 377
# Parcel 702 is success at time 281
# Parcel 711 is success at time 272
# Parcel 724 is success at time 364
# Parcel 765 is success at time 620
# Parcel 792 is success at time 428
# Parcel 846 is success at time 381
# Parcel 901 is success at time 279
# Parcel 992 is success at time 284
# Parcel 1068 is success at time 278
# Parcel 1099 is success at time 312
# Parcel 1101 is success at time 303
# Parcel 1117 is success at time 436
# Parcel 1124 is success at time 267
# Parcel 1162 is success at time 282
# Parcel 1166 is success at time 420
# Parcel 1167 is success at time 272
# Parcel 1217 is success at time 342
# Parcel 1223 is success at time 264
# Parcel 1284 is success at time 264
# Parcel 1298 is success at time 271
# Parcel 1309 is success at time 289
# Parcel 1330 is success at time 442
# Parcel 1335 is success at time 389
# Parcel 1366 is success at time 508
# Parcel 1400 is success at time 374
# Parcel 1406 is success at time 372
# Parcel 1455 is success at time 275
# Parcel 1474 is success at time 277
# Parcel 1559 is success at time 422
# Parcel 1602 is success at time 262
# Parcel 1608 is success at time 276
# Parcel 1622 is success at time 435
# Parcel 1649 is success at time 420
# Parcel 1713 is success at time 281
# Parcel 1730 is success at time 274
# Parcel 1832 is success at time 316
# Parcel 1931 is success at time 604
# Parcel 1943 is success at time 447
# Parcel 2001 is success at time 356
# Parcel 2039 is success at time 470
# Parcel 2083 is success at time 404
# Parcel 2098 is success at time 312
# Parcel 2149 is success at time 364
# Parcel 2150 is success at time 267
# Parcel 2164 is success at time 452
# Parcel 2193 is success at time 236
# Parcel 2210 is success at time 505
# Parcel 2220 is success at time 274
# Parcel 2229 is success at time 456
# Parcel 2248 is success at time 330
# Parcel 2309 is success at time 536
# Parcel 2339 is success at time 445
# Parcel 2350 is success at time 495
# Parcel 2418 is success at time 267
# Parcel 2482 is success at time 286
# Parcel 2495 is success at time 359
# Parcel 2539 is success at time 312
# Parcel 2641 is success at time 348
# Parcel 2664 is success at time 340
# Parcel 2690 is success at time 553
# Parcel 2711 is success at time 320
# Parcel 2729 is success at time 316
# Parcel 2753 is success at time 374
# Parcel 2770 is success at time 409
# Parcel 2784 is success at time 407
# Parcel 2790 is success at time 268
# Parcel 2861 is success at time 620
# Parcel 2927 is success at time 429
# Parcel 2952 is success at time 272
# Parcel 2959 is success at time 439
# parcel 2995 crossed x-boundary between t=635 and t=636
# Parcel 3023 is success at time 262
# Parcel 3024 is success at time 342
# Parcel 3068 is success at time 265
# Parcel 3085 is success at time 492
# Parcel 3101 is success at time 282
# Parcel 3104 is success at time 272
# Parcel 3106 is success at time 265
# Parcel 3150 is success at time 363
# Parcel 3184 is success at time 353
# Parcel 3187 is success at time 275
# Parcel 3192 is success at time 319
# Parcel 3216 is success at time 614
# Parcel 3220 is success at time 293
# Parcel 3283 is success at time 279
# Parcel 3291 is success at time 412
# Parcel 3320 is success at time 292
# Parcel 3359 is success at time 288
# Parcel 3436 is success at time 280
# Parcel 3452 is success at time 346
# Parcel 3453 is success at time 366
# Parcel 3516 is success at time 484
# Parcel 3526 is success at time 277
# Parcel 3549 is success at time 333
# Parcel 3583 is success at time 433
# Parcel 3585 is success at time 309
# Parcel 3601 is success at time 511
# Parcel 3624 is success at time 308
# Parcel 3655 is success at time 281
# Parcel 3713 is success at time 348
# Parcel 3722 is success at time 280
# Parcel 3731 is success at time 260
# Parcel 3765 is success at time 360
# Parcel 3796 is success at time 283
# Parcel 3823 is success at time 450
# Parcel 3838 is success at time 469
# Parcel 3848 is success at time 376
# Parcel 3854 is success at time 451
# Parcel 3870 is success at time 275
# Parcel 3873 is success at time 325
# Parcel 3901 is success at time 273
# Parcel 3904 is success at time 488
# Parcel 3912 is success at time 267
# Parcel 3926 is success at time 360
# Parcel 4065 is success at time 281
# Parcel 4067 is success at time 320
# Parcel 4073 is success at time 275
# Parcel 4104 is success at time 543
# Parcel 4163 is success at time 277
# Parcel 4193 is success at time 302
# Parcel 4195 is success at time 447
# Parcel 4208 is success at time 340
# Parcel 4217 is success at time 346
# Parcel 4223 is success at time 337
# Parcel 4254 is success at time 326
# Parcel 4342 is success at time 338
# Parcel 4365 is success at time 334
# Parcel 4375 is success at time 326
# Parcel 4389 is success at time 482
# Parcel 4457 is success at time 444
# Parcel 4466 is success at time 457
# Parcel 4497 is success at time 361
# Parcel 4507 is success at time 401
# Parcel 4568 is success at time 482
# Parcel 4654 is success at time 629
# Parcel 4683 is success at time 268
# Parcel 4720 is success at time 374
# Parcel 4777 is success at time 234
# Parcel 4801 is success at time 377
# Parcel 4862 is success at time 441
# Parcel 4885 is success at time 406
# Parcel 4916 is success at time 274
# Parcel 4935 is success at time 280
# Parcel 4950 is success at time 267
# Parcel 4982 is success at time 267
# Parcel 4984 is success at time 426
# Parcel 4985 is success at time 315
# Parcel 5004 is success at time 268
# Parcel 5041 is success at time 463
# Parcel 5100 is success at time 480
# Parcel 5126 is success at time 419
# Parcel 5212 is success at time 323
# Parcel 5228 is success at time 274
# Parcel 5256 is success at time 276
# Parcel 5274 is success at time 271
# Parcel 5307 is success at time 271
# Parcel 5316 is success at time 308
# Parcel 5347 is success at time 451
# Parcel 5385 is success at time 431
# parcel 5404 crossed x-boundary between t=591 and t=592
# Parcel 5410 is success at time 309
# Parcel 5432 is success at time 455
# Parcel 5446 is success at time 610
# Parcel 5475 is success at time 606
# Parcel 5530 is success at time 365
# Parcel 5609 is success at time 266
# Parcel 5634 is success at time 347
# Parcel 5645 is success at time 353
# Parcel 5648 is success at time 423
# Parcel 5679 is success at time 262
# Parcel 5681 is success at time 278
# Parcel 5770 is success at time 283
# Parcel 5811 is success at time 265
# Parcel 5826 is success at time 363
# Parcel 5841 is success at time 436
# Parcel 5890 is success at time 409
# Parcel 6042 is success at time 399
# Parcel 6138 is success at time 273
# Parcel 6245 is success at time 267
# Parcel 6249 is success at time 366
# Parcel 6259 is success at time 406
# Parcel 6265 is success at time 267
# Parcel 6274 is success at time 410
# Parcel 6286 is success at time 363
# Parcel 6365 is success at time 336
# Parcel 6404 is success at time 279
# Parcel 6439 is success at time 277
# Parcel 6480 is success at time 274
# Parcel 6495 is success at time 423
# Parcel 6523 is success at time 279
# Parcel 6559 is success at time 354
# Parcel 6570 is success at time 284
# Parcel 6571 is success at time 412
# Parcel 6608 is success at time 539
# Parcel 6625 is success at time 246
# Parcel 6664 is success at time 285
# Parcel 6669 is success at time 508
# Parcel 6705 is success at time 493
# Parcel 6717 is success at time 435
# Parcel 6763 is success at time 537
# Parcel 6858 is success at time 275
# Parcel 6869 is success at time 297
# Parcel 6874 is success at time 392
# Parcel 6879 is success at time 280
# Parcel 6967 is success at time 272
# Parcel 6968 is success at time 278
# Parcel 7040 is success at time 413
# Parcel 7099 is success at time 345
# Parcel 7110 is success at time 520
# Parcel 7127 is success at time 232
# Parcel 7183 is success at time 367
# Parcel 7185 is success at time 274
# Parcel 7196 is success at time 349
# Parcel 7276 is success at time 341
# Parcel 7330 is success at time 284
# Parcel 7334 is success at time 349
# Parcel 7350 is success at time 452
# Parcel 7360 is success at time 277
# Parcel 7510 is success at time 531
# Parcel 7582 is success at time 410
# Parcel 7616 is success at time 266
# Parcel 7623 is success at time 382
# Parcel 7640 is success at time 331
# Parcel 7644 is success at time 554
# Parcel 7660 is success at time 303
# Parcel 7719 is success at time 339
# Parcel 7724 is success at time 310
# Parcel 7771 is success at time 404
# Parcel 7809 is success at time 247
# Parcel 7813 is success at time 279
# Parcel 7858 is success at time 269
# Parcel 7935 is success at time 560
# Parcel 7953 is success at time 418
# Parcel 7990 is success at time 354
# Parcel 8044 is success at time 403
# Parcel 8058 is success at time 493
# Parcel 8102 is success at time 373
# Parcel 8158 is success at time 272
# Parcel 8167 is success at time 328
# Parcel 8180 is success at time 324
# Parcel 8203 is success at time 406
# Parcel 8242 is success at time 325
# Parcel 8272 is success at time 289
# Parcel 8291 is success at time 326
# Parcel 8356 is success at time 289
# Parcel 8416 is success at time 398
# Parcel 8431 is success at time 371
# Parcel 8479 is success at time 269
# Parcel 8596 is success at time 272
# Parcel 8607 is success at time 302
# Parcel 8632 is success at time 325
# Parcel 8639 is success at time 276
# Parcel 8644 is success at time 462
# Parcel 8650 is success at time 269
# Parcel 8787 is success at time 496
# Parcel 8806 is success at time 331
# Parcel 8830 is success at time 274
# Parcel 8833 is success at time 334
# Parcel 8849 is success at time 467
# Parcel 8853 is success at time 330
# Parcel 8889 is success at time 455
# Parcel 8940 is success at time 273
# Parcel 8951 is success at time 324
# Parcel 9037 is success at time 398
# Parcel 9051 is success at time 285
# Parcel 9109 is success at time 443
# Parcel 9136 is success at time 367
# Parcel 9177 is success at time 279
# Parcel 9193 is success at time 349
# Parcel 9321 is success at time 302
# Parcel 9369 is success at time 269
# Parcel 9375 is success at time 397
# Parcel 9425 is success at time 273
# Parcel 9451 is success at time 353
# Parcel 9452 is success at time 342
# Parcel 9552 is success at time 264
# Parcel 9576 is success at time 487
# Parcel 9592 is success at time 323
# Parcel 9602 is success at time 309
# Parcel 9608 is success at time 336
# Parcel 9613 is success at time 270
# Parcel 9643 is success at time 397
# Parcel 9671 is success at time 372
# Parcel 9696 is success at time 417
# Parcel 9700 is success at time 282
# Parcel 9734 is success at time 272
# Parcel 9794 is success at time 411
# Parcel 9832 is success at time 394
# Parcel 9876 is success at time 413
# Parcel 9889 is success at time 329
# Parcel 9925 is success at time 329
# Parcel 9978 is success at time 347
# Parcel 9980 is success at time 465
# Parcel 10030 is success at time 395
# Parcel 10031 is success at time 361
# Parcel 10042 is success at time 343
# Parcel 10073 is success at time 277
# Parcel 10101 is success at time 282
# Parcel 10114 is success at time 357
# Parcel 10115 is success at time 282
# Parcel 10118 is success at time 558
# Parcel 10134 is success at time 338
# Parcel 10135 is success at time 280
# Parcel 10191 is success at time 282
# Parcel 10202 is success at time 279
# Parcel 10208 is success at time 344
# Parcel 10230 is success at time 272
# Parcel 10303 is success at time 303
# Parcel 10305 is success at time 281
# Parcel 10325 is success at time 294
# Parcel 10350 is success at time 264
# Parcel 10352 is success at time 460
# Parcel 10385 is success at time 338
# Parcel 10417 is success at time 385
# Parcel 10508 is success at time 324
# Parcel 10544 is success at time 468
# Parcel 10617 is success at time 469
# Parcel 10625 is success at time 333
# Parcel 10678 is success at time 395
# Parcel 10691 is success at time 445
# Parcel 10779 is success at time 336
# Parcel 10786 is success at time 359
# Parcel 10787 is success at time 367
# Parcel 10794 is success at time 271
# Parcel 10939 is success at time 421
# Parcel 11002 is success at time 564
# Parcel 11004 is success at time 267
# Parcel 11006 is success at time 464
# Parcel 11066 is success at time 526
# Parcel 11093 is success at time 270
# Parcel 11130 is success at time 257
# Parcel 11143 is success at time 336
# Parcel 11153 is success at time 291
# Parcel 11166 is success at time 280
# Parcel 11250 is success at time 337
# Parcel 11255 is success at time 324
# Parcel 11271 is success at time 357
# Parcel 11283 is success at time 344
# Parcel 11367 is success at time 343
# Parcel 11417 is success at time 449
# Parcel 11473 is success at time 281
# Parcel 11496 is success at time 356
# Parcel 11599 is success at time 280
# Parcel 11637 is success at time 274
# Parcel 11644 is success at time 319
# Parcel 11669 is success at time 372
# Parcel 11687 is success at time 275
# Parcel 11705 is success at time 327
# Parcel 11715 is success at time 314
# parcel 11721 crossed x-boundary between t=419 and t=420
# Parcel 11766 is success at time 316
# Parcel 11784 is success at time 377
# Parcel 11825 is success at time 256
# Parcel 11855 is success at time 338
# Parcel 11990 is success at time 395
# Parcel 11995 is success at time 357
# Parcel 11998 is success at time 339
# Parcel 12021 is success at time 280
# Parcel 12022 is success at time 544
# Parcel 12042 is success at time 232
# Parcel 12076 is success at time 285
# Parcel 12078 is success at time 319
# Parcel 12100 is success at time 280
# Parcel 12161 is success at time 370
# Parcel 12165 is success at time 429
# Parcel 12184 is success at time 373
# Parcel 12215 is success at time 534
# Parcel 12222 is success at time 287
# Parcel 12234 is success at time 282
# Parcel 12264 is success at time 354
# Parcel 12333 is success at time 263
# Parcel 12334 is success at time 378
# Parcel 12383 is success at time 336
# Parcel 12406 is success at time 384
# Parcel 12412 is success at time 470
# Parcel 12428 is success at time 344
# Parcel 12463 is success at time 409
# Parcel 12475 is success at time 490
# Parcel 12483 is success at time 445
# Parcel 12489 is success at time 268
# Parcel 12503 is success at time 328
# Parcel 12598 is success at time 314
# Parcel 12600 is success at time 282
# Parcel 12603 is success at time 338
# Parcel 12610 is success at time 278
# Parcel 12637 is success at time 361
# Parcel 12698 is success at time 274
# Parcel 12762 is success at time 273
# Parcel 12829 is success at time 285
# Parcel 12838 is success at time 311
# Parcel 12862 is success at time 424
# Parcel 12868 is success at time 443
# Parcel 12870 is success at time 313
# Parcel 12942 is success at time 284
# Parcel 12944 is success at time 278
# Parcel 13036 is success at time 270
# Parcel 13051 is success at time 423
# Parcel 13062 is success at time 274
# Parcel 13082 is success at time 281
# Parcel 13101 is success at time 445
# Parcel 13104 is success at time 389
# Parcel 13231 is success at time 337
# Parcel 13251 is success at time 405
# Parcel 13280 is success at time 268
# Parcel 13302 is success at time 480
# Parcel 13316 is success at time 477
# Parcel 13326 is success at time 317
# Parcel 13384 is success at time 373
# Parcel 13422 is success at time 265
# Parcel 13461 is success at time 359
# Parcel 13478 is success at time 381
# Parcel 13487 is success at time 417
# Parcel 13514 is success at time 271
# Parcel 13525 is success at time 470
# Parcel 13634 is success at time 342
# Parcel 13641 is success at time 366
# Parcel 13643 is success at time 277
# Parcel 13696 is success at time 271
# Parcel 13730 is success at time 376
# Parcel 13732 is success at time 310
# Parcel 13738 is success at time 278
# Parcel 13762 is success at time 554
# Parcel 13778 is success at time 540
# Parcel 13792 is success at time 477
# Parcel 13891 is success at time 260
# Parcel 13894 is success at time 454
# Parcel 13951 is success at time 266
# Parcel 14069 is success at time 361
# Parcel 14080 is success at time 391
# Parcel 14099 is success at time 401
# Parcel 14102 is success at time 427
# Parcel 14105 is success at time 342
# Parcel 14108 is success at time 519
# Parcel 14112 is success at time 337
# Parcel 14169 is success at time 314
# Parcel 14276 is success at time 276
# Parcel 14284 is success at time 429
# Parcel 14300 is success at time 271
# Parcel 14326 is success at time 350
# Parcel 14381 is success at time 273
# Parcel 14401 is success at time 319
# Parcel 14428 is success at time 273
# Parcel 14457 is success at time 309
# Parcel 14461 is success at time 597
# Parcel 14468 is success at time 454
# Parcel 14514 is success at time 406
# Parcel 14542 is success at time 339
# Parcel 14567 is success at time 501
# Parcel 14670 is success at time 265
# Parcel 14744 is success at time 267
# Parcel 14751 is success at time 340
# Parcel 14757 is success at time 445
# Parcel 14814 is success at time 366
# Parcel 14820 is success at time 265
# Parcel 14834 is success at time 315
# Parcel 14836 is success at time 360
# Parcel 14842 is success at time 286
# Parcel 14873 is success at time 487
# Parcel 14907 is success at time 350
# Parcel 14946 is success at time 484
# Parcel 15005 is success at time 425
# Parcel 15019 is success at time 312
# Parcel 15057 is success at time 270
# Parcel 15066 is success at time 382
# Parcel 15074 is success at time 275
# Parcel 15078 is success at time 396
# Parcel 15110 is success at time 242
# Parcel 15213 is success at time 280
# Parcel 15311 is success at time 317
# Parcel 15315 is success at time 331
# Parcel 15328 is success at time 424
# Parcel 15338 is success at time 436
# Parcel 15390 is success at time 285
# Parcel 15415 is success at time 283
# Parcel 15425 is success at time 283
# Parcel 15473 is success at time 522
# Parcel 15490 is success at time 280
# Parcel 15516 is success at time 340
# Parcel 15565 is success at time 270
# Parcel 15614 is success at time 348
# Parcel 15651 is success at time 292
# Parcel 15708 is success at time 598
# Parcel 15713 is success at time 348
# Parcel 15750 is success at time 483
# Parcel 15796 is success at time 369
# Parcel 15850 is success at time 419
# Parcel 15867 is success at time 373
# Parcel 15868 is success at time 308
# Parcel 15870 is success at time 271
# Parcel 15903 is success at time 360
# Parcel 15970 is success at time 497
# Parcel 16072 is success at time 535
# Parcel 16133 is success at time 277
# Parcel 16174 is success at time 267
# Parcel 16183 is success at time 565
# Parcel 16192 is success at time 283
# Parcel 16215 is success at time 451
# Parcel 16251 is success at time 417
# Parcel 16300 is success at time 268
# Parcel 16330 is success at time 320
# Parcel 16331 is success at time 264
# Parcel 16426 is success at time 263
# Parcel 16431 is success at time 271
# Parcel 16492 is success at time 443
# Parcel 16557 is success at time 353
# Parcel 16571 is success at time 263
# Parcel 16598 is success at time 370
# Parcel 16627 is success at time 311
# Parcel 16655 is success at time 480
# Parcel 16678 is success at time 264
# Parcel 16697 is success at time 278
# Parcel 16743 is success at time 498
# Parcel 16802 is success at time 319
# Parcel 16813 is success at time 459
# Parcel 16831 is success at time 269
# Parcel 16833 is success at time 262
# Parcel 16873 is success at time 455
# Parcel 16890 is success at time 342
# Parcel 16898 is success at time 472
# Parcel 16921 is success at time 436
# Parcel 16952 is success at time 262
# Parcel 16965 is success at time 420
# Parcel 17004 is success at time 446
# Parcel 17043 is success at time 367
# Parcel 17059 is success at time 339
# Parcel 17060 is success at time 267
# Parcel 17084 is success at time 338
# Parcel 17094 is success at time 325
# Parcel 17128 is success at time 450
# Parcel 17170 is success at time 321
# Parcel 17179 is success at time 342
# Parcel 17209 is success at time 323
# Parcel 17257 is success at time 274
# Parcel 17310 is success at time 416
# Parcel 17344 is success at time 274
# Parcel 17407 is success at time 289
# Parcel 17420 is success at time 310
# Parcel 17456 is success at time 332
# Parcel 17519 is success at time 347
# Parcel 17540 is success at time 352
# Parcel 17569 is success at time 455
# Parcel 17613 is success at time 473
# Parcel 17635 is success at time 275
# Parcel 17638 is success at time 533
# Parcel 17786 is success at time 405
# Parcel 17820 is success at time 326
# Parcel 17946 is success at time 267
# Parcel 17962 is success at time 311
# Parcel 17972 is success at time 278
# Parcel 17999 is success at time 272
# Parcel 18004 is success at time 254
# Parcel 18022 is success at time 319
# Parcel 18027 is success at time 274
# Parcel 18037 is success at time 604
# Parcel 18041 is success at time 257
# Parcel 18044 is success at time 274
# Parcel 18108 is success at time 395
# Parcel 18132 is success at time 274
# Parcel 18152 is success at time 304
# Parcel 18164 is success at time 234
# Parcel 18203 is success at time 281
# Parcel 18241 is success at time 368
# Parcel 18278 is success at time 334
# Parcel 18289 is success at time 281
# Parcel 18307 is success at time 267
# Parcel 18315 is success at time 391
# Parcel 18360 is success at time 557
# Parcel 18388 is success at time 434
# Parcel 18436 is success at time 272
# Parcel 18440 is success at time 253
# Parcel 18478 is success at time 449
# Parcel 18593 is success at time 276
# Parcel 18695 is success at time 416
# Parcel 18746 is success at time 401
# Parcel 18811 is success at time 282
# Parcel 18843 is success at time 384
# Parcel 18877 is success at time 282
# Parcel 18995 is success at time 308
# Parcel 19093 is success at time 280
# Parcel 19107 is success at time 472
# Parcel 19112 is success at time 281
# Parcel 19138 is success at time 276
# Parcel 19145 is success at time 371
# Parcel 19166 is success at time 270
# Parcel 19215 is success at time 278
# Parcel 19223 is success at time 403
# Parcel 19224 is success at time 316
# Parcel 19234 is success at time 280
# Parcel 19251 is success at time 414
# Parcel 19253 is success at time 333
# Parcel 19260 is success at time 517
# Parcel 19265 is success at time 271
# Parcel 19385 is success at time 416
# Parcel 19427 is success at time 403
# Parcel 19454 is success at time 272
# Parcel 19507 is success at time 580
# Parcel 19526 is success at time 254
# Parcel 19570 is success at time 416
# Parcel 19596 is success at time 269
# Parcel 19599 is success at time 320
# Parcel 19604 is success at time 263
# Parcel 19618 is success at time 281
# Parcel 19704 is success at time 346
# Parcel 19710 is success at time 497
# Parcel 19798 is success at time 302
# Parcel 19833 is success at time 345
# Parcel 19895 is success at time 357
# Parcel 19928 is success at time 411
# Parcel 19991 is success at time 262
# Parcel 20023 is success at time 333
# Parcel 20057 is success at time 280
# Parcel 20097 is success at time 342
# Parcel 20121 is success at time 525
# Parcel 20122 is success at time 516
# Parcel 20125 is success at time 298
# Parcel 20151 is success at time 537
# Parcel 20155 is success at time 391
# Parcel 20172 is success at time 418
# Parcel 20179 is success at time 277
# Parcel 20211 is success at time 348
# Parcel 20247 is success at time 417
# Parcel 20254 is success at time 273
# Parcel 20264 is success at time 271
# Parcel 20303 is success at time 263
# Parcel 20392 is success at time 433
# Parcel 20405 is success at time 274
# Parcel 20449 is success at time 259
# Parcel 20468 is success at time 269
# Parcel 20499 is success at time 322
# Parcel 20504 is success at time 269
# Parcel 20579 is success at time 281
# Parcel 20585 is success at time 446
# Parcel 20595 is success at time 573
# Parcel 20597 is success at time 276
# Parcel 20633 is success at time 544
# Parcel 20650 is success at time 450
# Parcel 20729 is success at time 274
# Parcel 20731 is success at time 397
# Parcel 20744 is success at time 573
# Parcel 20831 is success at time 435
# Parcel 20838 is success at time 274
# Parcel 20858 is success at time 416
# Parcel 20899 is success at time 310
# Parcel 20925 is success at time 309
# Parcel 20938 is success at time 420
# Parcel 20958 is success at time 352
# Parcel 20964 is success at time 561
# Parcel 20991 is success at time 470
# Parcel 21042 is success at time 320
# Parcel 21049 is success at time 321
# Parcel 21075 is success at time 267
# Parcel 21083 is success at time 315
# Parcel 21118 is success at time 353
# Parcel 21141 is success at time 274
# Parcel 21142 is success at time 370
# Parcel 21351 is success at time 280
# Parcel 21371 is success at time 519
# Parcel 21492 is success at time 287
# Parcel 21535 is success at time 319
# Parcel 21567 is success at time 339
# Parcel 21574 is success at time 348
# Parcel 21624 is success at time 429
# Parcel 21643 is success at time 304
# Parcel 21653 is success at time 451
# Parcel 21684 is success at time 274
# Parcel 21705 is success at time 279
# Parcel 21712 is success at time 333
# Parcel 21746 is success at time 279
# Parcel 21754 is success at time 277
# Parcel 21778 is success at time 323
# Parcel 21803 is success at time 345
# Parcel 21815 is success at time 309
# Parcel 21817 is success at time 287
# Parcel 21822 is success at time 516
# Parcel 21876 is success at time 389
# Parcel 21951 is success at time 302
# Parcel 21960 is success at time 271
# Parcel 21986 is success at time 264
# Parcel 22032 is success at time 333
# Parcel 22047 is success at time 271
# Parcel 22068 is success at time 322
# Parcel 22072 is success at time 271
# Parcel 22080 is success at time 536
# Parcel 22116 is success at time 359
# parcel 22120 crossed x-boundary between t=312 and t=334
# Parcel 22137 is success at time 402
# Parcel 22315 is success at time 436
# Parcel 22404 is success at time 408
# Parcel 22472 is success at time 324
# Parcel 22500 is success at time 340
# Parcel 22544 is success at time 276
# Parcel 22573 is success at time 308
# Parcel 22599 is success at time 301
# Parcel 22602 is success at time 280
# Parcel 22643 is success at time 281
# Parcel 22697 is success at time 591
# Parcel 22725 is success at time 324
# Parcel 22727 is success at time 392
# Parcel 22749 is success at time 264
# Parcel 22786 is success at time 291
# Parcel 22798 is success at time 380
# Parcel 22800 is success at time 271
# Parcel 22820 is success at time 412
# Parcel 22854 is success at time 267
# Parcel 22857 is success at time 393
# Parcel 22861 is success at time 354
# Parcel 22927 is success at time 418
# Parcel 23029 is success at time 362
# Parcel 23060 is success at time 273
# Parcel 23065 is success at time 282
# Parcel 23122 is success at time 536
# Parcel 23136 is success at time 408
# Parcel 23153 is success at time 262
# Parcel 23160 is success at time 361
# Parcel 23195 is success at time 394
# Parcel 23234 is success at time 413
# Parcel 23236 is success at time 337
# Parcel 23247 is success at time 281
# Parcel 23332 is success at time 272
# Parcel 23364 is success at time 443
# Parcel 23393 is success at time 394
# Parcel 23454 is success at time 373
# Parcel 23468 is success at time 594
# Parcel 23473 is success at time 633
# Parcel 23507 is success at time 468
# Parcel 23530 is success at time 300
# Parcel 23566 is success at time 455
# Parcel 23570 is success at time 284
# Parcel 23587 is success at time 346
# Parcel 23601 is success at time 275
# Parcel 23646 is success at time 268
# Parcel 23690 is success at time 583
# Parcel 23726 is success at time 276
# Parcel 23736 is success at time 390
# Parcel 23742 is success at time 440
# Parcel 23751 is success at time 378
# Parcel 23755 is success at time 412
# Parcel 23775 is success at time 439
# Parcel 23782 is success at time 437
# Parcel 23794 is success at time 358
# Parcel 23831 is success at time 317
# Parcel 23869 is success at time 412
# Parcel 24012 is success at time 495
# Parcel 24019 is success at time 366
# parcel 24022 crossed x-boundary between t=316 and t=317
# Parcel 24061 is success at time 270
# Parcel 24106 is success at time 274
# Parcel 24165 is success at time 436
# Parcel 24213 is success at time 280
# Parcel 24232 is success at time 393
# Parcel 24246 is success at time 290
# Parcel 24249 is success at time 412
# Parcel 24258 is success at time 519
# Parcel 24405 is success at time 394
# Parcel 24424 is success at time 428
# Parcel 24443 is success at time 400
# Parcel 24481 is success at time 285
# Parcel 24493 is success at time 267
# Parcel 24501 is success at time 419
# Parcel 24518 is success at time 341
# Parcel 24525 is success at time 355
# Parcel 24549 is success at time 424
# Parcel 24602 is success at time 276
# Parcel 24603 is success at time 307
# Parcel 24615 is success at time 330
# Parcel 24616 is success at time 318
# Parcel 24617 is success at time 387
# Parcel 24622 is success at time 449
# Parcel 24627 is success at time 386
# Parcel 24628 is success at time 467
# Parcel 24709 is success at time 369
# Parcel 24750 is success at time 587
# Parcel 24786 is success at time 279
# Parcel 24791 is success at time 366
# Parcel 24844 is success at time 413
# Parcel 24895 is success at time 441
# Parcel 24955 is success at time 435
# Parcel 25091 is success at time 427
# Parcel 25096 is success at time 371
# Parcel 25123 is success at time 330
# Parcel 25130 is success at time 573
# Parcel 25146 is success at time 594
# Parcel 25178 is success at time 334
# Parcel 25234 is success at time 275
# Parcel 25260 is success at time 529
# Parcel 25283 is success at time 327
# Parcel 25312 is success at time 268
# Parcel 25320 is success at time 454
# Parcel 25326 is success at time 455
# Parcel 25335 is success at time 272
# Parcel 25339 is success at time 282
# Parcel 25349 is success at time 262
# Parcel 25363 is success at time 349
# Parcel 25375 is success at time 437
# Parcel 25399 is success at time 280
# Parcel 25485 is success at time 268
# Parcel 25496 is success at time 511
# Parcel 25517 is success at time 272
# Parcel 25522 is success at time 277
# Parcel 25563 is success at time 598
# Parcel 25606 is success at time 254
# Parcel 25617 is success at time 372
# Parcel 25619 is success at time 357
# Parcel 25622 is success at time 580
# Parcel 25648 is success at time 373
# Parcel 25653 is success at time 400
# Parcel 25656 is success at time 624
# Parcel 25689 is success at time 380
# Parcel 25697 is success at time 439
# Parcel 25710 is success at time 378
# Parcel 25750 is success at time 365
# Parcel 25840 is success at time 422
# Parcel 25862 is success at time 259
# Parcel 25863 is success at time 386
# Parcel 25868 is success at time 347
# Parcel 25896 is success at time 318
# Parcel 25929 is success at time 337
# Parcel 25942 is success at time 266
# Parcel 26107 is success at time 268
# Parcel 26203 is success at time 390
# Parcel 26219 is success at time 330
# Parcel 26248 is success at time 355
# Parcel 26267 is success at time 304
# Parcel 26302 is success at time 392
# Parcel 26330 is success at time 398
# Parcel 26344 is success at time 274
# Parcel 26365 is success at time 340
# Parcel 26370 is success at time 473
# Parcel 26391 is success at time 336
# parcel 26464 crossed x-boundary between t=561 and t=562
# Parcel 26487 is success at time 270
# Parcel 26498 is success at time 273
# Parcel 26506 is success at time 415
# Parcel 26513 is success at time 397
# Parcel 26581 is success at time 339
# Parcel 26615 is success at time 390
# Parcel 26637 is success at time 521
# Parcel 26673 is success at time 538
# Parcel 26686 is success at time 280
# Parcel 26695 is success at time 267
# Parcel 26746 is success at time 360
# Parcel 26848 is success at time 479
# Parcel 26862 is success at time 324
# Parcel 26871 is success at time 345
# Parcel 26876 is success at time 401
# Parcel 26954 is success at time 343
# Parcel 26989 is success at time 345
# Parcel 27010 is success at time 427
# Parcel 27013 is success at time 391
# Parcel 27100 is success at time 342
# Parcel 27176 is success at time 288
# Parcel 27181 is success at time 371
# Parcel 27239 is success at time 267
# Parcel 27251 is success at time 289
# Parcel 27332 is success at time 281
# Parcel 27354 is success at time 272
# Parcel 27375 is success at time 268
# Parcel 27408 is success at time 353
# Parcel 27433 is success at time 269
# Parcel 27472 is success at time 280
# Parcel 27475 is success at time 328
# Parcel 27476 is success at time 265
# Parcel 27488 is success at time 274
# Parcel 27491 is success at time 315
# Parcel 27550 is success at time 268
# Parcel 27585 is success at time 317
# Parcel 27590 is success at time 359
# Parcel 27628 is success at time 282
# Parcel 27670 is success at time 382
# Parcel 27702 is success at time 274
# Parcel 27717 is success at time 529
# Parcel 27745 is success at time 436
# Parcel 27778 is success at time 502
# Parcel 27782 is success at time 293
# Parcel 27820 is success at time 267
# Parcel 27824 is success at time 387
# Parcel 27827 is success at time 277
# Parcel 27829 is success at time 334
# Parcel 27853 is success at time 368
# Parcel 27864 is success at time 510
# Parcel 27866 is success at time 416
# Parcel 27899 is success at time 494
# Parcel 27901 is success at time 593
# Parcel 27935 is success at time 393
# Parcel 27959 is success at time 467
# Parcel 28017 is success at time 263
# Parcel 28030 is success at time 545
# Parcel 28040 is success at time 261
# Parcel 28044 is success at time 346
# Parcel 28087 is success at time 275
# Parcel 28201 is success at time 259
# Parcel 28277 is success at time 410
# Parcel 28297 is success at time 263
# parcel 28365 crossed x-boundary between t=575 and t=576
# Parcel 28463 is success at time 398
# Parcel 28482 is success at time 324
# Parcel 28537 is success at time 399
# Parcel 28539 is success at time 281
# Parcel 28566 is success at time 277
# Parcel 28568 is success at time 407
# Parcel 28576 is success at time 307
# Parcel 28595 is success at time 412
# Parcel 28607 is success at time 294
# Parcel 28643 is success at time 280
# Parcel 28684 is success at time 270
# Parcel 28716 is success at time 453
# Parcel 28742 is success at time 277
# Parcel 28813 is success at time 537
# Parcel 28874 is success at time 368
# Parcel 28892 is success at time 265
# Parcel 28903 is success at time 562
# Parcel 29005 is success at time 456
# Parcel 29020 is success at time 407
# parcel 29040 crossed x-boundary between t=569 and t=570
# Parcel 29073 is success at time 388
# Parcel 29080 is success at time 429
# Parcel 29085 is success at time 277
# Parcel 29086 is success at time 565
# Parcel 29100 is success at time 445
# Parcel 29169 is success at time 359
# Parcel 29430 is success at time 434
# Parcel 29431 is success at time 425
# Parcel 29440 is success at time 345
# Parcel 29492 is success at time 366
# Parcel 29523 is success at time 269
# Parcel 29525 is success at time 343
# Parcel 29558 is success at time 387
# Parcel 29619 is success at time 358
# Parcel 29704 is success at time 284
# Parcel 29713 is success at time 336
# Parcel 29720 is success at time 284
# Parcel 29735 is success at time 338
# Parcel 29748 is success at time 270
# Parcel 29755 is success at time 273
# Parcel 29784 is success at time 261
# Parcel 29845 is success at time 401
# Parcel 29857 is success at time 488
# Parcel 29910 is success at time 331
# Parcel 29932 is success at time 303
# Parcel 29969 is success at time 392
# parcel 29994 crossed x-boundary between t=459 and t=467
# Parcel 30039 is success at time 490
# Parcel 30047 is success at time 269
# Parcel 30070 is success at time 270
# Parcel 30084 is success at time 330
# Parcel 30105 is success at time 368
# Parcel 30163 is success at time 331
# Parcel 30169 is success at time 506
# Parcel 30183 is success at time 290
# Parcel 30202 is success at time 358
# Parcel 30251 is success at time 310
# Parcel 30284 is success at time 263
# Parcel 30305 is success at time 349
# Parcel 30378 is success at time 332
# Parcel 30418 is success at time 268
# Parcel 30431 is success at time 391
# Parcel 30445 is success at time 399
# Parcel 30466 is success at time 404
# Parcel 30514 is success at time 286
# Parcel 30536 is success at time 422
# Parcel 30546 is success at time 284
# Parcel 30562 is success at time 407
# Parcel 30568 is success at time 450
# Parcel 30633 is success at time 350
# Parcel 30647 is success at time 317
# Parcel 30650 is success at time 275
# Parcel 30667 is success at time 279
# Parcel 30701 is success at time 283
# Parcel 30711 is success at time 334
# Parcel 30745 is success at time 425
# Parcel 30762 is success at time 304
# Parcel 30765 is success at time 560
# Parcel 30770 is success at time 279
# Parcel 30799 is success at time 403
# Parcel 30816 is success at time 501
# Parcel 30837 is success at time 338
# Parcel 30841 is success at time 270
# Parcel 30890 is success at time 380
# Parcel 30903 is success at time 383
# Parcel 30950 is success at time 321
# Parcel 30981 is success at time 330
# Parcel 31014 is success at time 331
# parcel 31020 crossed x-boundary between t=558 and t=559
# Parcel 31022 is success at time 343
# Parcel 31057 is success at time 277
# Parcel 31067 is success at time 300
# Parcel 31074 is success at time 365
# Parcel 31076 is success at time 323
# Parcel 31090 is success at time 376
# Parcel 31166 is success at time 333
# Parcel 31233 is success at time 400
# Parcel 31240 is success at time 281
# Parcel 31243 is success at time 438
# Parcel 31294 is success at time 315
# Parcel 31381 is success at time 273
# Parcel 31395 is success at time 359
# Parcel 31426 is success at time 597
# Parcel 31427 is success at time 338
# Parcel 31472 is success at time 415
# Parcel 31516 is success at time 422
# Parcel 31519 is success at time 332
# Parcel 31535 is success at time 277
# Parcel 31549 is success at time 298
# Parcel 31565 is success at time 266
# Parcel 31586 is success at time 376
# Parcel 31588 is success at time 270
# Parcel 31593 is success at time 389
# Parcel 31610 is success at time 582
# Parcel 31665 is success at time 415
# Parcel 31708 is success at time 564
# Parcel 31763 is success at time 406
# Parcel 31791 is success at time 437
# Parcel 31904 is success at time 334
# Parcel 32003 is success at time 277
# Parcel 32027 is success at time 312
# Parcel 32029 is success at time 271
# Parcel 32036 is success at time 405
# Parcel 32040 is success at time 554
# Parcel 32084 is success at time 463
# Parcel 32091 is success at time 583
# Parcel 32105 is success at time 276
# Parcel 32202 is success at time 585
# Parcel 32227 is success at time 344
# Parcel 32258 is success at time 421
# Parcel 32290 is success at time 264
# Parcel 32327 is success at time 311
# Parcel 32354 is success at time 351
# Parcel 32365 is success at time 393
# Parcel 32366 is success at time 443
# Parcel 32388 is success at time 351
# Parcel 32444 is success at time 386
# Parcel 32599 is success at time 348
# parcel 32629 crossed x-boundary between t=393 and t=396
# Parcel 32632 is success at time 277
# Parcel 32680 is success at time 286
# Parcel 32729 is success at time 334
# Parcel 32735 is success at time 284
# Parcel 32749 is success at time 357
# Parcel 32763 is success at time 584
# Parcel 32816 is success at time 271
# Parcel 32821 is success at time 264
# Parcel 32829 is success at time 265
# Parcel 32836 is success at time 361
# Parcel 32897 is success at time 310
# Parcel 32934 is success at time 269
# Parcel 32965 is success at time 408
# Parcel 32974 is success at time 270
# Parcel 33004 is success at time 261
# Parcel 33018 is success at time 383
# Parcel 33042 is success at time 260
# Parcel 33089 is success at time 276
# Parcel 33100 is success at time 273
# Parcel 33239 is success at time 266
# Parcel 33305 is success at time 406
# Parcel 33367 is success at time 380
# Parcel 33368 is success at time 277
# Parcel 33371 is success at time 312
# Parcel 33391 is success at time 277
# Parcel 33399 is success at time 509
# Parcel 33416 is success at time 588
# Parcel 33549 is success at time 269
# Parcel 33561 is success at time 489
# Parcel 33566 is success at time 269
# Parcel 33595 is success at time 276
# Parcel 33603 is success at time 281
# Parcel 33604 is success at time 454
# Parcel 33629 is success at time 270
# Parcel 33673 is success at time 432
# Parcel 33740 is success at time 364
# Parcel 33760 is success at time 600
# Parcel 33795 is success at time 474
# Parcel 33808 is success at time 367
# Parcel 33816 is success at time 276
# Parcel 33869 is success at time 472
# Parcel 33884 is success at time 356
# Parcel 33915 is success at time 619
# Parcel 33945 is success at time 383
# Parcel 34102 is success at time 469
# Parcel 34127 is success at time 355
# Parcel 34154 is success at time 355
# Parcel 34157 is success at time 479
# Parcel 34160 is success at time 290
# Parcel 34210 is success at time 281
# Parcel 34243 is success at time 496
# Parcel 34311 is success at time 274
# Parcel 34397 is success at time 286
# Parcel 34409 is success at time 357
# Parcel 34503 is success at time 400
# Parcel 34530 is success at time 359
# Parcel 34569 is success at time 408
# Parcel 34609 is success at time 411
# Parcel 34613 is success at time 351
# Parcel 34656 is success at time 316
# Parcel 34668 is success at time 382
# Parcel 34696 is success at time 342
# Parcel 34735 is success at time 321
# Parcel 34774 is success at time 454
# Parcel 34782 is success at time 266
# Parcel 34786 is success at time 336
# Parcel 34790 is success at time 261
# Parcel 34797 is success at time 287
# Parcel 34867 is success at time 328
# Parcel 34877 is success at time 277
# Parcel 34907 is success at time 332
# Parcel 34976 is success at time 281
# Parcel 35129 is success at time 312
# Parcel 35157 is success at time 383
# Parcel 35175 is success at time 277
# Parcel 35269 is success at time 273
# Parcel 35295 is success at time 398
# Parcel 35336 is success at time 408
# Parcel 35379 is success at time 310
# Parcel 35394 is success at time 466
# Parcel 35399 is success at time 311
# Parcel 35403 is success at time 375
# Parcel 35408 is success at time 272
# Parcel 35416 is success at time 324
# Parcel 35425 is success at time 412
# Parcel 35463 is success at time 367
# Parcel 35508 is success at time 328
# Parcel 35600 is success at time 550
# Parcel 35659 is success at time 281
# Parcel 35668 is success at time 309
# Parcel 35671 is success at time 478
# Parcel 35672 is success at time 337
# Parcel 35677 is success at time 500
# Parcel 35754 is success at time 274
# Parcel 35780 is success at time 283
# Parcel 35806 is success at time 262
# Parcel 35846 is success at time 268
# Parcel 35858 is success at time 402
# Parcel 35859 is success at time 458
# Parcel 35895 is success at time 475
# Parcel 35939 is success at time 408
# Parcel 35989 is success at time 277
# Parcel 36046 is success at time 372
# Parcel 36058 is success at time 271
# Parcel 36059 is success at time 386
# Parcel 36067 is success at time 421
# Parcel 36083 is success at time 333
# Parcel 36107 is success at time 531
# Parcel 36115 is success at time 273
# Parcel 36133 is success at time 564
# Parcel 36205 is success at time 419
# Parcel 36224 is success at time 404
# Parcel 36276 is success at time 274
# Parcel 36282 is success at time 540
# parcel 36297 crossed x-boundary between t=317 and t=318
# Parcel 36361 is success at time 434
# Parcel 36387 is success at time 434
# Parcel 36406 is success at time 536
# Parcel 36418 is success at time 418
# Parcel 36582 is success at time 388
# Parcel 36604 is success at time 517
# Parcel 36676 is success at time 619
# Parcel 36721 is success at time 271
# Parcel 36743 is success at time 440
# Parcel 36790 is success at time 426
# Parcel 36797 is success at time 520
# Parcel 36849 is success at time 514
# Parcel 36854 is success at time 271
# Parcel 36918 is success at time 254
# Parcel 36967 is success at time 403
# Parcel 37019 is success at time 267
# Parcel 37033 is success at time 326
# Parcel 37044 is success at time 276
# Parcel 37111 is success at time 427
# Parcel 37137 is success at time 634
# Parcel 37160 is success at time 385
# Parcel 37166 is success at time 276
# Parcel 37176 is success at time 282
# Parcel 37196 is success at time 270
# Parcel 37206 is success at time 287
# Parcel 37216 is success at time 310
# Parcel 37236 is success at time 276
# Parcel 37400 is success at time 276
# Parcel 37431 is success at time 324
# Parcel 37435 is success at time 273
# Parcel 37536 is success at time 511
# Parcel 37589 is success at time 274
# Parcel 37624 is success at time 363
# Parcel 37635 is success at time 271
# Parcel 37639 is success at time 276
# Parcel 37667 is success at time 608
# Parcel 37735 is success at time 367
# Parcel 37745 is success at time 275
# Parcel 37861 is success at time 272
# Parcel 37915 is success at time 403
# Parcel 37923 is success at time 314
# Parcel 37932 is success at time 272
# Parcel 37987 is success at time 279
# Parcel 37993 is success at time 275
# Parcel 38009 is success at time 325
# Parcel 38069 is success at time 649
# Parcel 38099 is success at time 342
# Parcel 38129 is success at time 284
# Parcel 38148 is success at time 278
# Parcel 38173 is success at time 266
# Parcel 38224 is success at time 272
# Parcel 38241 is success at time 313
# Parcel 38364 is success at time 374
# Parcel 38404 is success at time 334
# Parcel 38464 is success at time 427
# Parcel 38491 is success at time 307
# Parcel 38492 is success at time 248
# Parcel 38518 is success at time 345
# Parcel 38520 is success at time 355
# Parcel 38572 is success at time 306
# Parcel 38576 is success at time 263
# Parcel 38637 is success at time 271
# Parcel 38638 is success at time 384
# Parcel 38703 is success at time 400
# Parcel 38771 is success at time 464
# Parcel 38791 is success at time 272
# Parcel 38826 is success at time 262
# Parcel 38856 is success at time 395
# Parcel 38903 is success at time 369
# Parcel 38965 is success at time 326
# Parcel 38991 is success at time 360
# Parcel 38996 is success at time 270
# Parcel 39000 is success at time 270
# Parcel 39001 is success at time 420
# Parcel 39008 is success at time 324
# Parcel 39017 is success at time 272
# Parcel 39051 is success at time 280
# Parcel 39058 is success at time 402
# Parcel 39132 is success at time 345
# Parcel 39133 is success at time 295
# Parcel 39135 is success at time 273
# Parcel 39146 is success at time 542
# Parcel 39152 is success at time 521
# Parcel 39173 is success at time 343
# Parcel 39219 is success at time 341
# Parcel 39220 is success at time 277
# Parcel 39249 is success at time 276
# Parcel 39304 is success at time 328
# Parcel 39305 is success at time 553
# Parcel 39357 is success at time 327
# Parcel 39409 is success at time 620
# Parcel 39416 is success at time 339
# Parcel 39418 is success at time 438
# Parcel 39494 is success at time 412
# Parcel 39541 is success at time 436
# Parcel 39588 is success at time 325
# Parcel 39590 is success at time 336
# Parcel 39592 is success at time 429
# Parcel 39599 is success at time 389
# Parcel 39643 is success at time 322
# Parcel 39648 is success at time 539
# Parcel 39649 is success at time 395
# Parcel 39650 is success at time 268
# Parcel 39653 is success at time 342
# Parcel 39659 is success at time 420
# Parcel 39662 is success at time 326
# Parcel 39698 is success at time 281
# Parcel 39736 is success at time 268
# Parcel 39750 is success at time 320
# Parcel 39753 is success at time 408
# Parcel 39776 is success at time 600
# Parcel 39778 is success at time 264
# Parcel 39810 is success at time 310
# Parcel 39823 is success at time 430
# Parcel 39871 is success at time 393
# Parcel 39877 is success at time 276
# Parcel 39918 is success at time 271
# Parcel 39941 is success at time 522
# Parcel 39968 is success at time 473
# Parcel 39992 is success at time 475
# Parcel 40010 is success at time 296
# Parcel 40032 is success at time 360
# Parcel 40114 is success at time 422
# Parcel 40198 is success at time 267
# Parcel 40259 is success at time 268
# Parcel 40273 is success at time 308
# Parcel 40316 is success at time 489
# Parcel 40327 is success at time 394
# Parcel 40420 is success at time 268
# Parcel 40444 is success at time 450
# Parcel 40453 is success at time 513
# Parcel 40464 is success at time 317
# Parcel 40507 is success at time 555
# Parcel 40569 is success at time 277
# Parcel 40637 is success at time 270
# Parcel 40651 is success at time 261
# Parcel 40668 is success at time 323
# Parcel 40699 is success at time 281
# Parcel 40709 is success at time 279
# Parcel 40712 is success at time 311
# Parcel 40837 is success at time 318
# Parcel 40839 is success at time 272
# Parcel 40871 is success at time 334
# Parcel 40918 is success at time 345
# Parcel 40978 is success at time 260
# Parcel 41004 is success at time 357
# Parcel 41016 is success at time 329
# Parcel 41027 is success at time 421
# Parcel 41045 is success at time 355
# Parcel 41069 is success at time 329
# Parcel 41095 is success at time 271
# Parcel 41132 is success at time 369
# Parcel 41336 is success at time 283
# Parcel 41365 is success at time 280
# Parcel 41370 is success at time 405
# Parcel 41415 is success at time 496
# Parcel 41425 is success at time 522
# Parcel 41448 is success at time 424
# Parcel 41473 is success at time 363
# Parcel 41510 is success at time 346
# Parcel 41521 is success at time 365
# Parcel 41528 is success at time 271
# Parcel 41593 is success at time 318
# Parcel 41657 is success at time 421
# Parcel 41682 is success at time 349
# Parcel 41712 is success at time 366
# Parcel 41713 is success at time 273
# Parcel 41744 is success at time 291
# Parcel 41777 is success at time 350
# Parcel 41853 is success at time 270
# ...
# Parcel 132111 is success at time 282
# Parcel 132117 is success at time 280
# Parcel 132139 is success at time 404
# Parcel 132148 is success at time 277
# Parcel 132178 is success at time 490
# Parcel 132190 is success at time 271
# Parcel 132199 is success at time 265
# Parcel 132215 is success at time 340
# Parcel 132263 is success at time 402
# Parcel 132269 is success at time 272
# Parcel 132294 is success at time 275
# Parcel 132296 is success at time 317
# Parcel 132431 is success at time 272
# Parcel 132435 is success at time 271
# Parcel 132437 is success at time 405
# Parcel 132469 is success at time 330
# Parcel 132477 is success at time 231
# Parcel 132505 is success at time 516
# Parcel 132512 is success at time 375
# Parcel 132522 is success at time 343
# Parcel 132547 is success at time 335
# Parcel 132550 is success at time 359
# Parcel 132558 is success at time 268
# Parcel 132561 is success at time 347
# Parcel 132572 is success at time 385
# Parcel 132603 is success at time 436
# Parcel 132612 is success at time 388
# Parcel 132621 is success at time 461
# Parcel 132628 is success at time 330
# Parcel 132654 is success at time 331
# Parcel 132697 is success at time 275
# Parcel 132702 is success at time 350
# Parcel 132801 is success at time 428
# Parcel 132822 is success at time 278
# Parcel 132893 is success at time 633
# Parcel 132901 is success at time 450
# Parcel 132931 is success at time 330
# Parcel 132938 is success at time 343
# Parcel 132953 is success at time 636
# Parcel 132961 is success at time 385
# Parcel 132973 is success at time 411
# Parcel 132977 is success at time 333
# Parcel 133107 is success at time 365
# Parcel 133127 is success at time 427
# Parcel 133130 is success at time 429
# Parcel 133189 is success at time 535
# Parcel 133215 is success at time 347
# Parcel 133241 is success at time 510
# Parcel 133261 is success at time 289
# Parcel 133298 is success at time 377
# Parcel 133300 is success at time 572
# Parcel 133313 is success at time 333
# Parcel 133427 is success at time 359
# Parcel 133508 is success at time 435
# Parcel 133606 is success at time 427
# Parcel 133729 is success at time 302
# Parcel 133741 is success at time 369
# Parcel 133757 is success at time 545
# Parcel 133770 is success at time 364
# Parcel 133780 is success at time 607
# Parcel 133805 is success at time 391
# Parcel 133806 is success at time 492
# Parcel 133869 is success at time 430
# Parcel 133928 is success at time 337
# Parcel 133937 is success at time 276
# Parcel 133940 is success at time 334
# Parcel 133965 is success at time 426
# Parcel 133996 is success at time 401
# Parcel 134008 is success at time 281
# Parcel 134017 is success at time 354
# Parcel 134062 is success at time 309
# Parcel 134068 is success at time 384
# Parcel 134072 is success at time 473
# Parcel 134121 is success at time 473
# Parcel 134172 is success at time 271
# Parcel 134177 is success at time 340
# Parcel 134180 is success at time 343
# Parcel 134215 is success at time 366
# Parcel 134227 is success at time 399
# Parcel 134249 is success at time 519
# Parcel 134363 is success at time 493
# Parcel 134366 is success at time 377
# Parcel 134378 is success at time 325
# Parcel 134392 is success at time 469
# Parcel 134417 is success at time 291
# Parcel 134430 is success at time 466
# Parcel 134478 is success at time 424
# Parcel 134517 is success at time 278
# Parcel 134537 is success at time 407
# Parcel 134569 is success at time 335
# Parcel 134604 is success at time 428
# Parcel 134620 is success at time 331
# Parcel 134638 is success at time 299
# parcel 134648 crossed x-boundary between t=379 and t=380
# Parcel 134667 is success at time 355
# Parcel 134744 is success at time 433
# Parcel 134762 is success at time 272
# Parcel 134829 is success at time 316
# Parcel 134837 is success at time 545
# Parcel 134948 is success at time 443
# Parcel 134970 is success at time 357
# Parcel 135003 is success at time 298
# Parcel 135019 is success at time 266
# Parcel 135040 is success at time 280
# Parcel 135042 is success at time 272
# Parcel 135050 is success at time 367
# Parcel 135084 is success at time 348
# Parcel 135112 is success at time 297
# Parcel 135158 is success at time 539
# Parcel 135188 is success at time 366
# Parcel 135234 is success at time 414
# Parcel 135288 is success at time 301
# Parcel 135331 is success at time 276
# Parcel 135332 is success at time 335
# Parcel 135352 is success at time 445
# Parcel 135356 is success at time 285
# Parcel 135382 is success at time 398
# Parcel 135464 is success at time 362
# Parcel 135469 is success at time 283
# Parcel 135473 is success at time 390
# Parcel 135479 is success at time 279
# Parcel 135535 is success at time 507
# Parcel 135583 is success at time 275
# Parcel 135613 is success at time 267
# Parcel 135658 is success at time 383
# Parcel 135661 is success at time 343
# Parcel 135701 is success at time 328
# Parcel 135717 is success at time 510
# Parcel 135750 is success at time 372
# Parcel 135759 is success at time 377
# Parcel 135760 is success at time 412
# Parcel 135775 is success at time 405
# Parcel 135788 is success at time 285
# Parcel 135845 is success at time 441
# Parcel 135851 is success at time 341
# Parcel 135867 is success at time 262
# Parcel 135940 is success at time 312
# Parcel 135995 is success at time 420
# Parcel 136006 is success at time 277
# Parcel 136018 is success at time 298
# Parcel 136044 is success at time 414
# Parcel 136142 is success at time 287
# Parcel 136183 is success at time 271
# Parcel 136251 is success at time 262
# Parcel 136287 is success at time 331
# Parcel 136300 is success at time 384
# Parcel 136304 is success at time 345
# Parcel 136367 is success at time 275
# Parcel 136370 is success at time 266
# Parcel 136414 is success at time 418
# Parcel 136454 is success at time 407
# Parcel 136470 is success at time 408
# Parcel 136496 is success at time 276
# Parcel 136508 is success at time 456
# Parcel 136520 is success at time 409
# Parcel 136580 is success at time 339
# Parcel 136614 is success at time 271
# Parcel 136616 is success at time 427
# Parcel 136650 is success at time 283
# Parcel 136672 is success at time 272
# Parcel 136685 is success at time 448
# Parcel 136724 is success at time 288
# Parcel 136784 is success at time 264
# Parcel 136803 is success at time 345
# Parcel 136819 is success at time 273
# Parcel 136846 is success at time 321
# Parcel 136849 is success at time 268
# Parcel 136918 is success at time 423
# Parcel 136920 is success at time 340
# Parcel 136947 is success at time 341
# Parcel 136963 is success at time 355
# Parcel 136973 is success at time 239
# Parcel 136992 is success at time 478
# Parcel 137010 is success at time 261
# Parcel 137055 is success at time 384
# Parcel 137067 is success at time 462
# Parcel 137070 is success at time 269
# Parcel 137159 is success at time 348
# Parcel 137172 is success at time 352
# Parcel 137258 is success at time 511
# Parcel 137399 is success at time 416
# Parcel 137507 is success at time 528
# Parcel 137513 is success at time 520
# Parcel 137543 is success at time 312
# Parcel 137555 is success at time 266
# Parcel 137615 is success at time 340
# Parcel 137616 is success at time 269
# Parcel 137625 is success at time 278
# Parcel 137629 is success at time 484
# Parcel 137636 is success at time 534
# Parcel 137674 is success at time 386
# Parcel 137721 is success at time 338
# Parcel 137751 is success at time 375
# Parcel 137753 is success at time 338
# Parcel 137770 is success at time 304
# Parcel 137788 is success at time 365
# Parcel 137961 is success at time 567
# Parcel 137965 is success at time 342
# Parcel 138058 is success at time 267
# Parcel 138074 is success at time 518
# Parcel 138125 is success at time 333
# Parcel 138136 is success at time 303
# Parcel 138155 is success at time 358
# Parcel 138161 is success at time 340
# Parcel 138197 is success at time 278
# Parcel 138201 is success at time 274
# Parcel 138236 is success at time 330
# Parcel 138255 is success at time 334
# Parcel 138270 is success at time 536
# Parcel 138288 is success at time 312
# Parcel 138298 is success at time 405
# Parcel 138313 is success at time 306
# Parcel 138335 is success at time 270
# Parcel 138358 is success at time 486
# Parcel 138387 is success at time 282
# Parcel 138469 is success at time 409
# Parcel 138476 is success at time 408
# Parcel 138486 is success at time 389
# Parcel 138508 is success at time 407
# Parcel 138548 is success at time 424
# Parcel 138586 is success at time 313
# Parcel 138612 is success at time 276
# Parcel 138638 is success at time 376
# Parcel 138699 is success at time 290
# Parcel 138781 is success at time 274
# Parcel 138811 is success at time 274
# Parcel 138817 is success at time 278
# Parcel 138851 is success at time 348
# Parcel 138856 is success at time 490
# Parcel 138868 is success at time 452
# Parcel 138877 is success at time 342
# Parcel 138909 is success at time 415
# Parcel 138922 is success at time 321
# Parcel 138979 is success at time 406
# Parcel 139018 is success at time 355
# Parcel 139038 is success at time 269
# Parcel 139044 is success at time 499
# Parcel 139058 is success at time 276
# Parcel 139059 is success at time 414
# Parcel 139135 is success at time 477
# Parcel 139204 is success at time 296
# Parcel 139212 is success at time 273
# Parcel 139226 is success at time 437
# Parcel 139247 is success at time 285
# Parcel 139259 is success at time 323
# Parcel 139291 is success at time 432
# Parcel 139310 is success at time 274
# Parcel 139369 is success at time 524
# Parcel 139373 is success at time 406
# Parcel 139379 is success at time 279
# parcel 139382 crossed x-boundary between t=369 and t=370
# Parcel 139424 is success at time 267
# Parcel 139429 is success at time 403
# Parcel 139521 is success at time 305
# Parcel 139525 is success at time 321
# Parcel 139545 is success at time 270
# Parcel 139563 is success at time 405
# Parcel 139586 is success at time 269
# Parcel 139661 is success at time 339
# Parcel 139694 is success at time 385
# Parcel 139706 is success at time 442
# Parcel 139781 is success at time 361
# Parcel 139787 is success at time 272
# Parcel 139836 is success at time 280
# Parcel 139858 is success at time 355
# Parcel 139916 is success at time 255
# Parcel 139926 is success at time 424
# Parcel 139937 is success at time 273
# Parcel 139941 is success at time 397
# Parcel 140031 is success at time 321
# Parcel 140044 is success at time 355
# Parcel 140083 is success at time 251
# Parcel 140107 is success at time 262
# Parcel 140108 is success at time 334
# Parcel 140110 is success at time 354
# Parcel 140112 is success at time 281
# Parcel 140127 is success at time 281
# Parcel 140152 is success at time 499
# Parcel 140165 is success at time 330
# Parcel 140219 is success at time 334
# Parcel 140231 is success at time 262
# Parcel 140245 is success at time 575
# Parcel 140267 is success at time 372
# Parcel 140288 is success at time 460
# Parcel 140295 is success at time 425
# Parcel 140303 is success at time 279
# Parcel 140305 is success at time 346
# Parcel 140331 is success at time 487
# Parcel 140348 is success at time 320
# Parcel 140366 is success at time 558
# Parcel 140407 is success at time 483
# Parcel 140425 is success at time 433
# Parcel 140480 is success at time 539
# Parcel 140502 is success at time 260
# Parcel 140512 is success at time 608
# Parcel 140517 is success at time 346
# Parcel 140562 is success at time 390
# Parcel 140580 is success at time 313
# Parcel 140670 is success at time 289
# parcel 140679 crossed x-boundary between t=498 and t=499
# Parcel 140749 is success at time 390
# Parcel 140761 is success at time 532
# Parcel 140783 is success at time 259
# Parcel 140791 is success at time 302
# Parcel 140811 is success at time 317
# Parcel 140837 is success at time 338
# Parcel 140882 is success at time 386
# Parcel 140909 is success at time 336
# Parcel 140962 is success at time 371
# Parcel 140979 is success at time 423
# Parcel 140993 is success at time 358
# Parcel 141011 is success at time 372
# Parcel 141032 is success at time 364
# Parcel 141051 is success at time 282
# Parcel 141060 is success at time 584
# Parcel 141077 is success at time 361
# Parcel 141082 is success at time 393
# Parcel 141103 is success at time 316
# Parcel 141114 is success at time 274
# Parcel 141189 is success at time 401
# Parcel 141206 is success at time 324
# Parcel 141251 is success at time 347
# Parcel 141279 is success at time 293
# Parcel 141286 is success at time 285
# Parcel 141299 is success at time 358
# Parcel 141318 is success at time 276
# Parcel 141347 is success at time 343
# Parcel 141361 is success at time 280
# Parcel 141375 is success at time 458
# Parcel 141417 is success at time 275
# Parcel 141467 is success at time 264
# Parcel 141475 is success at time 309
# Parcel 141546 is success at time 347
# Parcel 141559 is success at time 543
# Parcel 141653 is success at time 346
# Parcel 141684 is success at time 368
# Parcel 141696 is success at time 609
# Parcel 141719 is success at time 282
# Parcel 141724 is success at time 286
# Parcel 141757 is success at time 267
# Parcel 141776 is success at time 555
# Parcel 141858 is success at time 458
# Parcel 141865 is success at time 297
# Parcel 141885 is success at time 377
# Parcel 141891 is success at time 294
# Parcel 141953 is success at time 421
# Parcel 141988 is success at time 396
# Parcel 142050 is success at time 283
# Parcel 142057 is success at time 272
# Parcel 142084 is success at time 304
# Parcel 142094 is success at time 367
# Parcel 142121 is success at time 476
# Parcel 142188 is success at time 505
# Parcel 142199 is success at time 448
# Parcel 142223 is success at time 389
# Parcel 142371 is success at time 271
# Parcel 142372 is success at time 458
# Parcel 142388 is success at time 441
# Parcel 142421 is success at time 273
# Parcel 142471 is success at time 500
# Parcel 142472 is success at time 374
# Parcel 142516 is success at time 333
# Parcel 142546 is success at time 546
# Parcel 142601 is success at time 295
# Parcel 142605 is success at time 266
# Parcel 142652 is success at time 274
# Parcel 142655 is success at time 363
# Parcel 142682 is success at time 424
# Parcel 142695 is success at time 373
# Parcel 142711 is success at time 421
# Parcel 142729 is success at time 268
# Parcel 142732 is success at time 383
# Parcel 142750 is success at time 500
# Parcel 142787 is success at time 342
# parcel 142794 crossed x-boundary between t=327 and t=329
# Parcel 142829 is success at time 429
# Parcel 142851 is success at time 277
# Parcel 142913 is success at time 269
# Parcel 142915 is success at time 521
# Parcel 142929 is success at time 276
# Parcel 142983 is success at time 384
# Parcel 142992 is success at time 272
# Parcel 142993 is success at time 520
# Parcel 143049 is success at time 269
# Parcel 143245 is success at time 339
# Parcel 143266 is success at time 480
# Parcel 143295 is success at time 266
# Parcel 143326 is success at time 265
# Parcel 143374 is success at time 451
# Parcel 143384 is success at time 329
# Parcel 143423 is success at time 327
# parcel 143430 crossed x-boundary between t=309 and t=325
# Parcel 143446 is success at time 485
# Parcel 143447 is success at time 448
# Parcel 143541 is success at time 621
# Parcel 143551 is success at time 274
# Parcel 143568 is success at time 274
# Parcel 143666 is success at time 456
# Parcel 143809 is success at time 262
# Parcel 143846 is success at time 555
# Parcel 143918 is success at time 270
# Parcel 143953 is success at time 384
# Parcel 143993 is success at time 377
# Parcel 144037 is success at time 379
# Parcel 144082 is success at time 265
# Parcel 144094 is success at time 272
# Parcel 144098 is success at time 365
# Parcel 144145 is success at time 301
# Parcel 144201 is success at time 464
# Parcel 144202 is success at time 338
# Parcel 144223 is success at time 419
# Parcel 144229 is success at time 272
# Parcel 144272 is success at time 263
# Parcel 144287 is success at time 445
# Parcel 144305 is success at time 268
# Parcel 144321 is success at time 273
# Parcel 144332 is success at time 250
# Parcel 144425 is success at time 254
# Parcel 144430 is success at time 543
# Parcel 144453 is success at time 427
# Parcel 144462 is success at time 280
# Parcel 144500 is success at time 364
# Parcel 144510 is success at time 427
# Parcel 144556 is success at time 271
# Parcel 144581 is success at time 583
# Parcel 144614 is success at time 404
# Parcel 144627 is success at time 384
# Parcel 144644 is success at time 266
# Parcel 144662 is success at time 397

# %%
#CORRECTING DATA PARCEL ID BASED ON JOB NUMBER
#####################################################
out_arr[np.where(np.any(out_arr != 0, axis=1))[0],0]+=index_adjust #*needed for job array*+=index_adjust #*needed for job array*
save_arr[np.where(np.any(save_arr != 0, axis=1))[0],0]+=index_adjust #*needed for job array*+=index_adjust #*needed for job array*
save2_arr[np.where(np.any(save2_arr != 0, axis=1))[0],0]+=index_adjust #*needed for job array*+=index_adjust #*needed for job array*

# %%
#REMOVING BLANK ROWS
#####################################################
def remove_zero_rows(arr):
    arr = arr[~np.all(arr == 0, axis=1)]
    return arr
out_arr=remove_zero_rows(out_arr)
save_arr=remove_zero_rows(save_arr)
save2_arr=remove_zero_rows(save2_arr)

# %%
# #Storing output and save data
#USES H5 FILE
###################################################################################################################################
out_file = dir + f'Project_Algorithms/Tracking_Algorithms/trackout/parcel_tracking_{res}_{t_res}_{Np_str}_{job_id}.h5'
with h5py.File(out_file, 'w') as hf:
    hf.create_dataset('out_arr', data=out_arr, compression="gzip")
    hf.create_dataset('save_arr', data=save_arr, compression="gzip")
    hf.create_dataset('save2_arr', data=save2_arr, compression="gzip")

end_time = time.time(); elapsed_time = end_time - start_time; print(f"Total Elapsed Time: {elapsed_time} seconds")
# Out:
# Total Elapsed Time: 275.4219493865967 seconds

# %%
check_memory()
# Out:
# Top 10 objects with highest memory usage
# {'parcel_z': '2232.11 MB', 'parcel_x': '2232.11 MB', 'W': '2232.11 MB', 'Z': '1116.06 MB', 'Y': '1116.06 MB', 'X': '1116.06 MB', 'LFC': '558.03 MB', 'LCL': '558.03 MB', 'ascend_lst': '6.68 MB', 'save2_arr': '0.51 MB'}
#
# 11.16776 GB in use overall

# %%
# #Storing output and save data
# #OLD, USES NETCDF, H5 IS RECOMMENDED INSTEAD HERE
# ###################################################################################################################################
# ds=xr.Dataset({
#     'out_arr': (['rows', 'columns'], out_arr.astype(float)),
#     'save_arr': (['rows', 'columns'], save_arr.astype(float)),
#     'save2_arr': (['rows', 'columns'], save2_arr.astype(float)),
# })


# out_file = dir+f'Project_Algorithms/Tracking_Algorithms/trackout/parcel_tracking_{res}_{t_res}_{Np_str}_{job_id}.nc'
# ds.to_netcdf(out_file)
# ###########################################################################################################################
# end_time = time.time(); elapsed_time = end_time - start_time; print(f"Total Elapsed Time: {elapsed_time} seconds")

# %%
############################################################
#Run after finishing job_array
recombine=False #KEEP FALSE WHEN JOB_ARRAY IS RUNNING
# recombine=True

# %%
# #OLD USING NC
# if recombine==True:
#     #combine all job output arrays 
#     import numpy as np
#     import matplotlib.pyplot as plt
#     import xarray as xr
#     import os; import time
#     dir='/mnt/lustre/koa/koastore/torri_group/air_directory/DCI-Project/'
    
#     num_jobs=60#350 #***
#     for job_id in range(1, num_jobs+1):
#         if np.mod(job_id,50)==0: print(f'job_id = {job_id}')
#         # Open the dataset and append it to the list
#         if job_id == 1: 
#             in_file=dir+f'Project_Algorithms/Tracking_Algorithms/trackout/parcel_tracking_{res}_{t_res}_{Np_str}_{job_id}.h5'
            
#             out_arr = xr.open_dataset(in_file)['out_arr']
#             save_arr = xr.open_dataset(in_file)['save_arr']
#         elif job_id >= 2: 
#             in_file = dir+f'Project_Algorithms/Tracking_Algorithms/trackout/parcel_tracking_{res}_{t_res}_{Np_str}_{job_id}.h5'
            
#             out2 = xr.open_dataset(in_file)['out_arr']
#             save2 = xr.open_dataset(in_file)['save_arr']
#             out_arr=np.concatenate((out_arr, out2), axis=0)
#             save_arr=np.concatenate((save_arr, save2), axis=0)
#     ds=xr.Dataset({
#         'out_arr': (['rows', 'columns'], out_arr.astype(float)),
#         'save_arr': (['rows', 'columns'], save_arr.astype(float)),
#     })
#     out_file=dir+f'Project_Algorithms/Tracking_Algorithms/parcel_tracking_{res}_{t_res}_{Np_str}.h5'
#     ds.to_netcdf(out_file)

# %%
#combine all job output arrays 
if recombine == True:
    num_jobs = 350 #60
    var_names = ['out_arr', 'save_arr', 'save2_arr']
    recombined_arrays = {}  # Store final arrays here

    def MakeUnique(arr):
        return np.unique(arr, axis=0)
    def get_total_count(var_name):
        return sum(
            h5py.File(dir + f'Project_Algorithms/Tracking_Algorithms/trackout/parcel_tracking_{res}_{t_res}_{Np_str}_{job_id}.h5', 'r')[var_name].shape[0]
            for job_id in range(1, num_jobs + 1)
        )

    def load_file(job_id, var_name):
        in_file = dir + f'Project_Algorithms/Tracking_Algorithms/trackout/parcel_tracking_{res}_{t_res}_{Np_str}_{job_id}.h5'
        with h5py.File(in_file, 'r') as hf:
            arr = hf[var_name][:]
        return arr

    # Preallocate arrays
    for var_name in var_names:
        total_count = get_total_count(var_name)
        recombined_arrays[var_name] = np.zeros((total_count, 3), dtype=np.int32)

    # Fill arrays
    for var_name in var_names:
        print(f"Combining data for {var_name}")
        left_ind = 0
        for job_id in range(1, num_jobs + 1):
            if job_id % 50 == 0:
                print(f"{var_name}: processing job {job_id}")
            arr = load_file(job_id, var_name)
            n_rows = arr.shape[0]; right_ind = left_ind + n_rows
            recombined_arrays[var_name][left_ind:right_ind, :] = arr
            left_ind = right_ind

    #Make Unique
    for var_name in var_names:
        recombined_arrays[var_name]=MakeUnique(recombined_arrays[var_name])
        
    # Write to file
    out_file = dir + f'Project_Algorithms/Tracking_Algorithms/parcel_tracking_{res}_{t_res}_{Np_str}.h5'
    with h5py.File(out_file, 'w') as hf:
        for var_name in var_names:
            
            hf.create_dataset(var_name, data=recombined_arrays[var_name], compression="gzip")
# Out:
# Combining data for out_arr
# out_arr: processing job 50
# out_arr: processing job 100
# out_arr: processing job 150
# out_arr: processing job 200
# out_arr: processing job 250
# out_arr: processing job 300
# out_arr: processing job 350
# Combining data for save_arr
# save_arr: processing job 50
# save_arr: processing job 100
# save_arr: processing job 150
# save_arr: processing job 200
# save_arr: processing job 250
# save_arr: processing job 300
# save_arr: processing job 350
# Combining data for save2_arr
# save2_arr: processing job 50
# save2_arr: processing job 100
# save2_arr: processing job 150
# save2_arr: processing job 200
# save2_arr: processing job 250
# save2_arr: processing job 300
# save2_arr: processing job 350

# %%
# #LOADING BACK IN
# def load_file():
#     in_file=dir+f'Project_Algorithms/Tracksing_Algorithms/parcel_tracking_{res}_{t_res}_{Np_str}.h5'
#     with h5py.File(in_file, 'r') as hf:
#         out_arr=hf['out_arr'][:]
#         save_arr=hf['save_arr'][:]
#         save2_arr=hf['save2_arr'][:]
#     return out_arr,save_arr,save2_arr
# [out_arr,save_arr,save2_arr]=load_file()

# %%
# #TESTING
# out_file = dir + f'Project_Algorithms/Tracking_Algorithms/parcel_tracking_{res}_{t_res}_{Np_str}.h5'
# with h5py.File(out_file, 'r') as hf:
#     test=hf['out_arr'][0:232]
# np.all(test==out_arr)
